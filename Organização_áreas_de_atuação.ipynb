# %%
import pandas as pd;
import os;
import pathlib;
import re

# %%
base = pd.read_csv('base_tratada.csv')

# %%
base
# Out:
#         Unnamed: 0      id                                               Nome  \
# 0                0       1     Secretaria de Cidadania e Diversidade Cultural
# 1                1       2                                        Marcos Lima
# 2                2       6                                             Branca
# 3                3       7                                               SCDC
# 4                4       8                       Plataforma Rede Cultura Viva
# ...            ...     ...                                                ...
# 140682      146749  302034  Centro de Estudo Pesquisa e Intervenção Ribeir...
# 140683      146750  302036                                                ABS
# 140684      146751  302039                                         CEPI-NEVES
# 140685      146752  302041                                    Aryadne Barbosa
# 140686      146753  302046                             Eliezer A. de Oliveira
#
# ...

# %% [markdown]
# ### Tratamento dos dados

# %%
#Excluindo colunas vazias
colunas_para_excluir = colunas_para_excluir = [
   'Nome', 'Localização_pública', 'Geolocalização', 'Descrição_curta', 
    'Descrição_longa', 'Status', 'E-mail', 'Telefone', 
    'Endereço', 'Município', 'UF', 'Estado', 'Mesorregião', 'Unnamed: 0', 'Termos_Limpos', 'Termos']
base = base.drop(columns=colunas_para_excluir)

base
# Out:
#             id                                         Área        Estado_mapa
# 0            1                              Gestão Cultural   DISTRITO FEDERAL
# 1            2  Gestão Cultural, Música, Artesanato, Outros          SAO PAULO
# 2            6                                       Teatro   DISTRITO FEDERAL
# 3            7                         Antropologia, Outros  RIO GRANDE DO SUL
# 4            8                                          NaN  RIO GRANDE DO SUL
# ...        ...                                          ...                ...
# 140682  302034                                          NaN                NaN
# 140683  302036                                          NaN                NaN
# 140684  302039                                          NaN                NaN
# 140685  302041                                       Outros                NaN
# 140686  302046                         Educação, Literatura     SANTA CATARINA
#
# ...

# %%
base['Área'] = base['Área'].str.split(', ')
base = base.explode('Área')
base
# Out:
#             id             Área       Estado_mapa
# 0            1  Gestão Cultural  DISTRITO FEDERAL
# 1            2  Gestão Cultural         SAO PAULO
# 1            2           Música         SAO PAULO
# 1            2       Artesanato         SAO PAULO
# 1            2           Outros         SAO PAULO
# ...        ...              ...               ...
# 140683  302036              NaN               NaN
# 140684  302039              NaN               NaN
# 140685  302041           Outros               NaN
# 140686  302046         Educação    SANTA CATARINA
# 140686  302046       Literatura    SANTA CATARINA
#
# [447966 rows x 3 columns]

# %%
termos_distintos = base['Área'].unique()
for termo in termos_distintos:
    print(termo)

num_unique_terms = len(termos_distintos)

print(f"Number of unique terms: {num_unique_terms}")
# Out:
# Gestão Cultural
# Música
# Artesanato
# Outros
# Teatro
# Antropologia
# nan
# Cultura Digital
# Artes Visuais
# Cultura Popular
# Literatura
# Mídias Sociais
# Patrimônio Material
# Arte de Rua
# Circo
# Cultura LGBT
# Economia Criativa
# Filosofia
# Jornalismo
# Livro
# Comunicação
# Cultura Negra
# Educação
# Leitura
# Patrimônio Imaterial
# Produção Cultural
# artes visuais
# cultura popular
# literatura
# música
# teatro
# arte de rua
# artesanato
# circo
# dança
# economia criativa
# gestão cultural
# comunicação
# cultura negra
# educação
# fotografia
# patrimônio imaterial
# sociologia
# Novas Mídias
# Arte Digital
# Audiovisual
# Design
# Meio Ambiente
# Sociologia
# Fotografia
# Cultura Indígena
# Gastronomia
# audiovisual
# pesquisa
# livro
# cultura digital
# leitura
# produção cultural
# Moda
# Televisão
# Cinema
# Esporte
# Dança
# Pesquisa
# cinema
# arte digital
# cultura estrangeira (imigrantes)
# cultura lgbt
# esporte
# meio ambiente
# mídias sociais
# ...

# %%
mapping = {
    'Gestão Cultural': 'Cultura',
    'Música': 'Artes',
    'Artesanato': 'Artes',
    'Outros': 'Outros',
    'nan': 'Outros',
    'Teatro': 'Artes',
    'Antropologia': 'Ciências Humanas',
    'Cultura Digital': 'Cultura',
    'Artes Visuais': 'Artes',
    'Cultura Popular': 'Cultura',
    'Literatura': 'Literatura',
    'Mídias Sociais': 'Comunicação',
    'Patrimônio Material': 'Artes',
    'Arte de Rua': 'Artes',
    'Circo': 'Artes',
    'Cultura LGBT': 'Política',
    'Economia Criativa': 'Outros',
    'Filosofia': 'Ciências Humanas',
    'Jornalismo': 'Comunicação',
    'Livro': 'Literatura',
    'Comunicação': 'Comunicação',
    'Cultura Negra': 'Cultura',
    'Educação': 'Educação',
    'Leitura': 'Literatura',
    'Patrimônio Imaterial': 'Outros',
    'Produção Cultural': 'Cultura',
    'artes visuais': 'Artes',
    'cultura popular': 'Cultura',
    'literatura': 'Literatura',
    'música': 'Artes',
    'teatro': 'Artes',
    'arte de rua': 'Artes',
    'artesanato': 'Artes',
    'circo': 'Artes',
    'dança': 'Artes',
    'economia criativa': 'Outros',
    'gestão cultural': 'Cultura',
    'comunicação': 'Comunicação',
    'cultura negra': 'Cultura',
    'educação': 'Educação',
    'fotografia': 'Comunicação',
    'patrimônio imaterial': 'Outros',
    'sociologia': 'Ciências Humanas',
    'Novas Mídias': 'Comunicação',
    'Arte Digital': 'Artes',
    'Audiovisual': 'Comunicação',
    'Design': 'Comunicação',
    'Meio Ambiente': 'Meio Ambiente',
    'Sociologia': 'Ciências Humanas',
    'Fotografia': 'Comunicação',
    'Cultura Indígena': 'Cultura',
    'Gastronomia': 'Cultura',
    'audiovisual': 'Comunicação',
    'pesquisa': 'Outros',
    'livro': 'Literatura',
    'cultura digital': 'Cultura',
    'leitura': 'Literatura',
    'produção cultural': 'Cultura',
    'Moda': 'Artes',
    'Televisão': 'Comunicação',
    'Cinema': 'Comunicação',
    'Esporte': 'Outros',
    'Dança': 'Artes',
    'Pesquisa': 'Outros',
    'cinema': 'Comunicação',
    'arte digital': 'Artes',
    'cultura estrangeira (imigrantes)': 'Cultura',
    'cultura lgbt': 'Política',
    'esporte': 'Outros',
    'meio ambiente': 'Meio Ambiente',
    'mídias sociais': 'Comunicação',
    'patrimônio material': 'Outros',
    'saúde': 'Saúde',
    'gastronomia': 'Outros',
    'história': 'Ciências Humanas',
    'Saúde': 'Saúde',
    'Turismo': 'Outros',
    'Arquivo': 'Outros',
    'Rádio': 'Comunicação',
    'História': 'Ciências Humanas',
    'Museu': 'Artes',
    'antropologia': 'Ciências Humanas',
    'museu': 'Artes',
    'filosofia': 'Ciências Humanas',
    'jornalismo': 'Comunicação',
    'televisão': 'Comunicação',
    'rádio': 'Comunicação',
    'cultura indígena': 'Cultura',
    'novas mídias': 'Comunicação',
    'turismo': 'Outros',
    'Patrimônio Cultural': 'Cultura',
    'jogos eletrônicos': 'Comunicação',
    'moda': 'Artes',
    'Arqueologia': 'Ciências Humanas',
    'Jogos Eletrônicos': 'Comunicação',
    'Ópera': 'Artes',
    'Arquitetura-Urbanismo': 'Arquitetura e Urbanismo',
    'Cultura Estrangeira (imigrantes)': 'Cultura',
    'direito autoral': 'Comunicação',
    'design': 'Comunicação',
    'Cultura Cigana': 'Cultura',
    'Direito Autoral': 'Comunicação',
    'Artes Circenses': 'Artes',
    'arquivo': 'Outros',
    'arqueologia': 'Ciências Humanas',
    'arquitetura-urbanismo': 'Arquitetura e Urbanismo',
    'cultura cigana': 'Cultura',
    'arte terapia': 'Artes',
    'biblioteca comunitária': 'Literatura',
    'cine + cultura': 'Cultura',
    'agroecologia': 'Meio Ambiente',
    'agente cultura viva': 'Cultura',
    'cultura de terreiro': 'Cultura',
    'demais atividades correlatas a cultura popular': 'Cultura',
    'cultura de redes': 'Cultura',
    'dança e canto coral': 'Artes',
    'intercambio cultural': 'Cultura',
    'agentes': 'Outros',
    'danca': 'Artes',
    'teatro estudantil': 'Artes',
    'artistas agentes culturais': 'Artes',
    'fortalecimento de cultura de rede local': 'Cultura',
    'intercâmbio cultural': 'Cultura',
    'acervos museológicos': 'Outros',
    'turismo de base comunitária': 'Outros',
    'ponto de memória': 'Outros',
    'tradicionalismo': 'Outros',
    'marchetaria': 'Outros',
    'literatura infantil': 'Literatura',
    'permacultura e cultura hacker': 'Outros',
    'exposições': 'Artes',
    'fabricação de obras de arte': 'Artes',
    'culturas urbanas': 'Cultura',
    'mostras culturais': 'Cultura',
    'festas calendarizadas populares': 'Cultura',
    'grafite': 'Artes',
    'dj e mc': 'Artes',
    'festa folclórica': 'Cultura',
    'ainda não fui contemplado (minc)': 'Outros',
    'bumba meu boi': 'Cultura',
    'hip hop': 'Artes',
    'diversidade': 'Política',
    'danças': 'Artes',
    'capoeira': 'Artes',
    'Ciência Política': 'Ciências Humanas',
    'Gestor Publico de Cultura': 'Cultura',
    'Banda': 'Artes',
    'Biblioteca': 'Literatura',
    'Orquestra': 'Artes',
    'Opera': 'Artes',
    'Coral': 'Artes',
    'Capoeira': 'Artes',
    'Carnaval': 'Cultura',
    'cultura': 'Cultura',
    'Agroecologia': 'Meio Ambiente'
}

# Função para mapear os valores para a nova coluna de Grande Área
def map_grande_area(value):
    return mapping.get(value, 'Outros')

# Aplicando a função ao DataFrame
base['Grande_area'] = base['Área'].apply(map_grande_area)

base
# Out:
#             id             Área       Estado_mapa Grande_area
# 0            1  Gestão Cultural  DISTRITO FEDERAL     Cultura
# 1            2  Gestão Cultural         SAO PAULO     Cultura
# 1            2           Música         SAO PAULO       Artes
# 1            2       Artesanato         SAO PAULO       Artes
# 1            2           Outros         SAO PAULO      Outros
# ...        ...              ...               ...         ...
# 140683  302036              NaN               NaN      Outros
# 140684  302039              NaN               NaN      Outros
# 140685  302041           Outros               NaN      Outros
# 140686  302046         Educação    SANTA CATARINA    Educação
# 140686  302046       Literatura    SANTA CATARINA  Literatura
#
# [447966 rows x 4 columns]

# %%
# Dicionário de mapeamento
padronizacao = {
    'gestão cultural': 'Gestão Cultural',
    'música': 'Música',
    'artesanato': 'Artesanato',
    'outros': 'Outros',
    'nan': 'Outros',
    'teatro': 'Teatro',
    'antropologia': 'Antropologia',
    'cultura digital': 'Cultura Digital',
    'artes visuais': 'Artes Visuais',
    'cultura popular': 'Cultura Popular',
    'literatura': 'Literatura',
    'mídias sociais': 'Mídias Sociais',
    'patrimônio material': 'Patrimônio Material',
    'arte de rua': 'Arte de Rua',
    'circo': 'Circo',
    'cultura lgbt': 'Cultura LGBT',
    'economia criativa': 'Economia Criativa',
    'filosofia': 'Filosofia',
    'jornalismo': 'Jornalismo',
    'livro': 'Livro',
    'comunicação': 'Comunicação',
    'cultura negra': 'Cultura Negra',
    'educação': 'Educação',
    'leitura': 'Leitura',
    'patrimônio imaterial': 'Patrimônio Imaterial',
    'produção cultural': 'Produção Cultural',
    'dança': 'Dança',
    'fotografia': 'Fotografia',
    'novas mídias': 'Novas Mídias',
    'arte digital': 'Arte Digital',
    'audiovisual': 'Audiovisual',
    'design': 'Design',
    'meio ambiente': 'Meio Ambiente',
    'cultura indígena': 'Cultura Indígena',
    'gastronomia': 'Gastronomia',
    'pesquisa': 'Pesquisa',
    'moda': 'Moda',
    'televisão': 'Televisão',
    'cinema': 'Cinema',
    'esporte': 'Esporte',
    'cultura estrangeira (imigrantes)': 'Cultura Estrangeira (imigrantes)',
    'saúde': 'Saúde',
    'história': 'História',
    'turismo': 'Turismo',
    'arquivo': 'Arquivo',
    'rádio': 'Rádio',
    'museu': 'Museu',
    'arqueologia': 'Arqueologia',
    'jogos eletrônicos': 'Jogos Eletrônicos',
    'ópera': 'Ópera',
    'arquitetura-urbanismo': 'Arquitetura-Urbanismo',
    'direito autoral': 'Direito Autoral',
    'cultura cigana': 'Cultura Cigana',
    'artes circenses': 'Artes Circenses',
    'arte terapia': 'Arte Terapia',
    'biblioteca comunitária': 'Biblioteca Comunitária',
    'cine + cultura': 'Cine + Cultura',
    'agroecologia': 'Agroecologia',
    'agente cultura viva': 'Agente Cultura Viva',
    'cultura de terreiro': 'Cultura de Terreiro',
    'cultura de redes': 'Cultura de Redes',
    'intercâmbio cultural': 'Intercâmbio Cultural',
    'acervos museológicos': 'Acervos Museológicos',
    'ponto de memória': 'Ponto de Memória',
    'tradicionalismo': 'Tradicionalismo',
    'literatura infantil': 'Literatura Infantil',
    'permacultura e cultura hacker': 'Permacultura e Cultura Hacker',
    'exposições': 'Exposições',
    'fabricação de obras de arte': 'Fabricação de Obras de Arte',
    'culturas urbanas': 'Culturas Urbanas',
    'mostras culturais': 'Mostras Culturais',
    'festas calendarizadas populares': 'Festas Calendarizadas Populares',
    'grafite': 'Grafite',
    'dj e mc': 'DJ e MC',
    'festa folclórica': 'Festa Folclórica',
    'bumba meu boi': 'Bumba Meu Boi',
    'hip hop': 'Hip Hop',
    'diversidade': 'Diversidade',
    'capoeira': 'Capoeira',
    'ciência política': 'Ciência Política',
    'gestor publico de cultura': 'Gestor Público de Cultura',
    'banda': 'Banda',
    'biblioteca': 'Biblioteca',
    'orquestra': 'Orquestra',
    'opera': 'Ópera',
    'coral': 'Coral',
    'carnaval': 'Carnaval',
    'cultura': 'Cultura'
}

# Função para padronizar os termos
def padronizar_termo(termo):
    if isinstance(termo, float):
        return 'Outros'
    return padronizacao.get(termo.lower(), termo.title())

# Aplicando a função ao DataFrame
base['Área'] = base['Área'].apply(padronizar_termo)

base
# Out:
#             id             Área       Estado_mapa Grande_area
# 0            1  Gestão Cultural  DISTRITO FEDERAL     Cultura
# 1            2  Gestão Cultural         SAO PAULO     Cultura
# 1            2           Música         SAO PAULO       Artes
# 1            2       Artesanato         SAO PAULO       Artes
# 1            2           Outros         SAO PAULO      Outros
# ...        ...              ...               ...         ...
# 140683  302036           Outros               NaN      Outros
# 140684  302039           Outros               NaN      Outros
# 140685  302041           Outros               NaN      Outros
# 140686  302046         Educação    SANTA CATARINA    Educação
# 140686  302046       Literatura    SANTA CATARINA  Literatura
#
# [447966 rows x 4 columns]

# %%
termos_distintos = base['Grande_area'].unique()
for termo in termos_distintos:
    print(termo)

num_unique_terms = len(termos_distintos)

print(f"Number of unique terms: {num_unique_terms}")
# Out:
# Cultura
# Artes
# Outros
# Ciências Humanas
# Literatura
# Comunicação
# Política
# Educação
# Meio Ambiente
# Saúde
# Arquitetura e Urbanismo
# Number of unique terms: 11

# %% [markdown]
# ### Exportação da base

# %%
base.to_csv(r"C:\Users\DSilva\Downloads\MUHDA - PNAB\areas_de_atuacao.csv")
base.to_excel(r"C:\Users\DSilva\Downloads\MUHDA - PNAB\areas_de_atuacao.xlsx")
